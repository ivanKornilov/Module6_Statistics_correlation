# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# Задача 2
# В конкурсе красоты участвовали десять девушек. Разыгрывались призы жюри и зрителей. Можно ли на уровне значимости 0,05 считать, что мнения жюри и зрителей зависимы? Что можно сказать о силе и направленности зависимости? Места, присуждённые девушкам жюри и зрителями, записаны в таблицу в соответствии с номерами участниц:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Математическая запись задачи и гипотез:
# ![image.png](attachment:image.png)

# %%
x = np.array([8,2,9,6,4,5,3,7,10,1])

# %%
y = np.array([10,7,8,2,5,1,6,3,9,4])

# %%
# коэфф.спирмена:
stats.spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=0.406060606060606, pvalue=0.24428229408662638)

# %%
# Н0 принимается на уровне значимости 0,05 или 0,1  === зависимость слабая положительная
# зависимость средней силы

# %%
# коэфф.кендала
stats.kendalltau(x,y)
# Out:
# KendalltauResult(correlation=0.24444444444444444, pvalue=0.38071979717813054)

# %%
# Н0 принимается на уровне значимости 0,05 или 0,1   === зависимость слабая положительная
# зависимость средней силы
